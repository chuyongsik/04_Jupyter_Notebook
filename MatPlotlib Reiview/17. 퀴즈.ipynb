# %%
s

data = {
    '영화' : ['명량', '극한직업', '신과함께-죄와 벌', '국제시장', '괴물', '도둑들', '7번방의 선물', '암살'],
    '개봉 연도' : [2014, 2019, 2017, 2014, 2006, 2012, 2013, 2015],
    '관객 수' : [1761, 1626, 1441, 1426, 1301, 1298, 1281, 1270], # (단위 : 만 명)
    '평점' : [8.88, 9.20, 8.73, 9.16, 8.62, 7.64, 8.83, 9.10]
}
df = pd.DataFrame(data)
df
# Out:
#           영화  개봉 연도  관객 수    평점
# 0         명량   2014  1761  8.88
# 1       극한직업   2019  1626  9.20
# 2  신과함께-죄와 벌   2017  1441  8.73
# 3       국제시장   2014  1426  9.16
# 4         괴물   2006  1301  8.62
# 5        도둑들   2012  1298  7.64
# 6    7번방의 선물   2013  1281  8.83
# 7         암살   2015  1270  9.10

# %%
plt.figure(figsize=(10, 6))
plt.bar(df['영화'], df['평점'], color='green')
plt.title('국내 Top 8 영화 평점 정보')
plt.xlabel('영화 제목')
plt.xticks(rotation=90)
plt.ylabel('평점')
# Out:
# Text(0, 0.5, '평점')

# %%
df_group = df.groupby('개봉 연도').mean()
df_group
# Out:
# C:\Users\GS\AppData\Local\Temp\ipykernel_51764\747250585.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_group = df.groupby('개봉 연도').mean()
#          관객 수    평점
# 개봉 연도
# 2006   1301.0  8.62
# 2012   1298.0  7.64
# 2013   1281.0  8.83
# 2014   1593.5  9.02
# 2015   1270.0  9.10
# 2017   1441.0  8.73
# 2019   1626.0  9.20

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_group.index, df_group['평점'], color='green', marker='o')
plt.title('연도별 평점 변화')
plt.xlabel('개봉 연도')
plt.ylabel('평점')
plt.xticks([2005, 2010, 2015, 2020])
plt.ylim(7,10)
# Out:
# (7.0, 10.0)

# %%
df['평점 9점 이상']= "9점 미만"
df.loc[df['평점'] >= 9, '평점 9점 이상'] = "9점 이상"
df
# Out:
#           영화  개봉 연도  관객 수    평점 평점 9점 이상
# 0         명량   2014  1761  8.88    9점 미만
# 1       극한직업   2019  1626  9.20    9점 이상
# 2  신과함께-죄와 벌   2017  1441  8.73    9점 미만
# 3       국제시장   2014  1426  9.16    9점 이상
# 4         괴물   2006  1301  8.62    9점 미만
# 5        도둑들   2012  1298  7.64    9점 미만
# 6    7번방의 선물   2013  1281  8.83    9점 미만
# 7         암살   2015  1270  9.10    9점 이상

# %%
df2=df.groupby('평점 9점 이상').count()['영화'] / df['영화'].count()
df2
# Out:
# 평점 9점 이상
# 9점 미만    0.625
# 9점 이상    0.375
# Name: 영화, dtype: float64

# %%
plt.pie(df2, labels=df2.index, autopct='%.1f%%', colors=['darkorange', 'blue'],startangle=0, counterclock=False)
plt.legend(loc=(1.2, 0.5))

# %%
print("%s is a string, %d is an integer, %.2f is a floating point number, %.1f%% is a percentage number" % ("Hello", 42, 3.14159,5.235))
# Out:
# Hello is a string, 42 is an integer, 3.14 is a floating point number, 5.2% is a percentage number

# %%
filt = df['평점'] >= 9
values = [len(df[filt]), len(df[~filt])]
labels = ['9점 이상', '9점 미만']

plt.pie(values, labels=labels, autopct='%.1f%%', colors=['darkorange', 'blue'],startangle=0
        )
plt.legend(loc=(1.2, 0.5))
