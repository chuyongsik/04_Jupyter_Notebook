# %% [markdown]
# # 13. 원그래프

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family']='MalGun Gothic'
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus']=False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
values =[30,25,20,13,10,2]
labes=['Python','Java','C','C#', 'C++','Etc']

plt.pie(values, labels=labes, autopct='%.1f%%', startangle=90, counterclock=False, explode=(0.2,0.1,0,0,0,0))
plt.show()

# %%
"""
This code creates a pie chart using Matplotlib library.
It takes a list of values, labels, and explode values as input.
The explode values determine the offset of each wedge from the center of the pie.
The pie chart is displayed using plt.show().
"""

values =[30,25,20,13,10,2]
labes=['Python','Java','C','C#', 'C++','Etc']
explode=[0.05]*6
print(explode)

plt.pie(values, labels=labes, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode)
plt.show()
# Out:
# [0.05, 0.05, 0.05, 0.05, 0.05, 0.05]

# %%
plt.pie(values, labels=labes, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode, shadow=True)
plt.legend(loc=(1.2,0.5))
plt.show()

# %%
plt.pie(values, labels=labes, autopct='%.1f%%', startangle=90, counterclock=False, explode=explode, shadow=True)
plt.title("언어별 선호도")
plt.legend(loc=(1.2,0.5), title='언어별 선호도')
plt.show()
