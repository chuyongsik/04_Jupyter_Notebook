# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x=[1,2,3]
y=[2,4,8]
plt.plot(x,y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x00000275C1ED3090>]

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x,y)
plt.title("Line Graph")
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title("꺾은 선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은 선 그래프')
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yschu\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family']='HYGungSo-Bold'
matplotlib.rcParams['font.size'] = 15 # 글자크기
matplotlib.rcParams['axes.unicode_minus']=False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.plot(x,y)
plt.title("꺽은선 그래프")
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXNonUnicode',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'cmsy10',
#  'DejaVu Sans Mono',
#  'cmtt10',
#  'STIXSizeFiveSym',
#  'STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'cmmi10',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'DejaVu Serif',
#  'cmr10',
#  'STIXSizeOneSym',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'DejaVu Sans',
#  'cmss10',
#  'cmb10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Sans',
#  'Bell MT',
#  'Cooper Black',
#  'Palatino Linotype',
#  'Microsoft YaHei',
#  'Microsoft Tai Le',
#  'Consolas',
#  'Lucida Bright',
#  'Comic Sans MS',
#  'Bodoni MT',
#  'Yu Gothic',
#  'Rockwell',
#  'Constantia',
#  'Arial',
#  'Batang',
#  'High Tower Text',
#  'Microsoft JhengHei',
#  'Constantia',
#  'Candara',
#  'Gigi',
#  'Gill Sans Ultra Bold',
#  'MS Reference Sans Serif',
#  'Segoe Script',
#  'Franklin Gothic Medium',
#  'Rockwell Condensed',
#  'Impact',
#  'Palatino Linotype',
#  'Castellar',
#  'Segoe MDL2 Assets',
#  'Corbel',
#  'Corbel',
#  'Tw Cen MT',
#  'Lucida Handwriting',
#  'HYGothic-Extra',
#  'Times New Roman',
#  'Arial',
#  'Calibri',
#  'HYPost-Light',
#  'Candara',
#  'Calibri',
#  'Kunstler Script',
#  'Segoe UI',
#  'Gill Sans Ultra Bold Condensed',
#  'Arial',
#  'Rockwell',
#  'Microsoft JhengHei',
#  'Lucida Sans Typewriter',
#  'Jokerman',
#  'SimSun-ExtB',
#  'Franklin Gothic Demi Cond',
#  'Viner Hand ITC',
#  'Sans Serif Collection',
#  'Harrington',
#  'Courier New',
#  'Myanmar Text',
#  'Goudy Old Style',
#  'Microsoft Yi Baiti',
#  'LG Smart UI',
#  'Elephant',
#  'Microsoft New Tai Lue',
#  'Malgun Gothic',
#  'Tahoma',
#  'Times New Roman',
#  'French Script MT',
#  'Niagara Engraved',
#  'Lucida Bright',
#  'Garamond',
#  'Malgun Gothic',
#  'Colonna MT',
#  'Segoe Print',
#  'Century Schoolbook',
#  'Footlight MT Light',
#  'Book Antiqua',
#  'Verdana',
#  'Wingdings 2',
#  'Lucida Sans',
#  'Segoe UI',
#  'High Tower Text',
#  'Segoe UI',
#  'Perpetua Titling MT',
#  'Bodoni MT',
#  'Forte',
#  'Bodoni MT',
#  'Georgia',
#  'Californian FB',
#  'Goudy Stout',
#  'Elephant',
#  'Microsoft PhagsPa',
#  'Script MT Bold',
#  'Tahoma',
#  'Century Gothic',
#  'Perpetua',
#  'Perpetua',
#  'Broadway',
#  'Goudy Old Style',
#  'Sylfaen',
#  'Book Antiqua',
#  'Verdana',
#  'Franklin Gothic Demi',
#  'Arial',
#  'Bookman Old Style',
#  'MS Outlook',
#  'Trebuchet MS',
#  'Maiandra GD',
#  'Gulim',
#  'Franklin Gothic Medium',
#  'LG PC',
#  'Arial',
#  'Bookshelf Symbol 7',
#  'Perpetua',
#  'Candara',
#  'Consolas',
#  'Courier New',
#  'Calisto MT',
#  'Segoe UI',
#  'Perpetua Titling MT',
#  'Rage Italic',
#  'Calibri',
#  'Ink Free',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Dubai',
#  'Franklin Gothic Heavy',
#  'Bookman Old Style',
#  'Eras Bold ITC',
#  'Bell MT',
#  'Gadugi',
#  'Ebrima',
#  'Lucida Sans',
#  'Perpetua',
#  'Copperplate Gothic Bold',
#  'Blackadder ITC',
#  'Poor Richard',
#  'Book Antiqua',
#  'Bradley Hand ITC',
#  'Calisto MT',
#  'Microsoft New Tai Lue',
#  'Bodoni MT',
#  'MingLiU-ExtB',
#  'Tw Cen MT Condensed',
#  'Wide Latin',
#  'Franklin Gothic Book',
#  'Segoe UI Historic',
#  'Microsoft YaHei',
#  'Rockwell Extra Bold',
#  'Eras Demi ITC',
#  'Calibri',
#  'Lucida Bright',
#  'Arial',
#  'Eras Light ITC',
#  'Constantia',
#  'Trebuchet MS',
#  'Garamond',
#  'HYHeadLine-Medium',
#  'Sitka',
#  'Cambria',
#  'Gill Sans MT',
#  'Lucida Fax',
#  'Segoe Print',
#  'Harlow Solid Italic',
#  'Bodoni MT',
#  'Cambria',
#  'Bell MT',
#  'Arial',
#  'Lucida Fax',
#  'Gill Sans MT',
#  'Monotype Corsiva',
#  'Bookman Old Style',
#  'Tw Cen MT',
#  'Playbill',
#  'Berlin Sans FB',
#  'Candara',
#  'Gill Sans MT',
#  'Segoe UI',
#  'Yu Gothic',
#  'Constantia',
#  'Bernard MT Condensed',
#  'Chiller',
#  'Century Schoolbook',
#  'Parchment',
#  'Palatino Linotype',
#  'Dubai',
#  'Sitka',
#  'Onyx',
#  'Gill Sans MT Ext Condensed Bold',
#  'Gabriola',
#  'Magneto',
#  'Copperplate Gothic Light',
#  'Ami R',
#  'Rockwell Condensed',
#  'Microsoft YaHei',
#  'Consolas',
#  'Lucida Console',
#  'Ravie',
#  'Imprint MT Shadow',
#  'Gloucester MT Extra Condensed',
#  'Trebuchet MS',
#  'Century',
#  'Consolas',
#  'Comic Sans MS',
#  'Arial Rounded MT Bold',
#  'SWGamekeys MT',
#  'Eras Medium ITC',
#  'Pyunji R',
#  'Lucida Sans Typewriter',
#  'Times New Roman',
#  'Nirmala UI',
#  'Bookman Old Style',
#  'HYPost-Medium',
#  'Juice ITC',
#  'Arial',
#  'HYMyeongJo-Extra',
#  'Brush Script MT',
#  'Lucida Fax',
#  'Gill Sans MT',
#  'Agency FB',
#  'Californian FB',
#  'Segoe Fluent Icons',
#  'Niagara Solid',
#  'Curlz MT',
#  'Comic Sans MS',
#  'Nirmala UI',
#  'Georgia',
#  'Javanese Text',
#  'Segoe UI',
#  'HoloLens MDL2 Assets',
#  'Tw Cen MT',
#  'Showcard Gothic',
#  'MS Reference Specialty',
#  'Edwardian Script ITC',
#  'Britannic Bold',
#  'Bodoni MT',
#  'Snap ITC',
#  'Haettenschweiler',
#  'Magic R',
#  'LG Smart UI',
#  'Webdings',
#  'Georgia',
#  'Century Schoolbook',
#  'LG Smart UI',
#  'Lucida Bright',
#  'Modern No. 20',
#  'Tw Cen MT',
#  'Californian FB',
#  'Bodoni MT',
#  'Corbel',
#  'Microsoft JhengHei',
#  'HYGothic-Medium',
#  'OCR A Extended',
#  'Symbol',
#  'Microsoft PhagsPa',
#  'Franklin Gothic Heavy',
#  'Mongolian Baiti',
#  'Bodoni MT',
#  'Goudy Old Style',
#  'HYSinMyeongJo-Medium',
#  'Century Gothic',
#  'Dubai',
#  'Lucida Fax',
#  'Trebuchet MS',
#  'Microsoft Tai Le',
#  'Papyrus',
#  'Vladimir Script',
#  'Candara',
#  'Palace Script MT',
#  'Gill Sans MT Condensed',
#  'Bodoni MT',
#  'Times New Roman',
#  'Arial',
#  'Century Gothic',
#  'Franklin Gothic Book',
#  'Corbel',
#  'Calibri',
#  'Rockwell',
#  'SimSun',
#  'Leelawadee UI',
#  'Bodoni MT',
#  'Cambria',
#  'Lucida Sans Unicode',
#  'Calisto MT',
#  'LG Smart UI',
#  'Headline R',
#  'Lucida Sans',
#  'Bahnschrift',
#  'Tw Cen MT Condensed Extra Bold',
#  'Segoe UI',
#  'Nirmala UI',
#  'Yu Gothic',
#  'Cambria',
#  'Century Gothic',
#  'Lucida Sans',
#  'Stencil',
#  'Berlin Sans FB Demi',
#  'HYGraphic-Medium',
#  'Tempus Sans ITC',
#  'Lucida Calligraphy',
#  'MoeumT R',
#  'Kristen ITC',
#  'Segoe UI Emoji',
#  'Myanmar Text',
#  'Pristina',
#  'Lucida Sans Typewriter',
#  'HYGungSo-Bold',
#  'Yet R',
#  'Corbel',
#  'Franklin Gothic Demi',
#  'Wingdings',
#  'Georgia',
#  'Courier New',
#  'Bodoni MT',
#  'New Gulim',
#  'Wingdings 3',
#  'Centaur',
#  'Engravers MT',
#  'Rockwell',
#  'Segoe UI',
#  'Algerian',
#  'Informal Roman',
#  'Segoe UI',
#  'HYShortSamul-Medium',
#  'Malgun Gothic',
#  'Felix Titling',
#  'Leelawadee UI',
#  'Segoe UI Variable',
#  'Microsoft Himalaya',
#  'Vivaldi',
#  'Verdana',
#  'Segoe UI',
#  'Mistral',
#  'MT Extra',
#  'MS Gothic',
#  'Book Antiqua',
#  'Courier New',
#  'HYPMokGak-Bold',
#  'Ebrima',
#  'Calisto MT',
#  'Agency FB',
#  'Segoe UI Symbol',
#  'MV Boli',
#  'Comic Sans MS',
#  'Garamond',
#  'Franklin Gothic Medium Cond',
#  'Old English Text MT',
#  'Corbel',
#  'Leelawadee UI',
#  'Candara',
#  'Calibri',
#  'Baskerville Old Face',
#  'Yu Gothic',
#  'Bauhaus 93',
#  'Dubai',
#  'Gadugi',
#  'Segoe UI',
#  'Tw Cen MT Condensed',
#  'Segoe Script',
#  'Freestyle Script',
#  'Lucida Sans Typewriter',
#  'Microsoft Sans Serif',
#  'Matura MT Script Capitals',
#  'Palatino Linotype',
#  'Berlin Sans FB',
#  'Verdana']

# %%
plt.plot([-1,0,1],[-5,-1,2])
